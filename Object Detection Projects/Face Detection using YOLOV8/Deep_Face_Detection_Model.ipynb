# %% [markdown]
# ## Setup and get data ##

# %%
import os, time, uuid, cv2
import shutil
import random
def PRINT() -> None: print('-'*80)

# %%
IMAGES_PATH = os.path.join('data', 'images')
NUMBER_IMGS = 30

# %%
def count_images_in_directory(directory_path):
    """

    """
    
    files = os.listdir(directory_path)
    image_files = [file for file in files if file.lower().endswith(('.jpg', '.jpeg', '.png'))]
    return len(image_files)

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    _, frame = cap.read()

    # Take single image sample by pressing on the 't' key
    if cv2.waitKey(1) & 0xFF == ord('t'):
        imgname = os.path.join(IMAGES_PATH, '{}.jpg'.format(uuid.uuid1()))
        cv2.imwrite(imgname, frame)
        
    cv2.imshow('Image Collection', frame)
    
    if cv2.waitKey(1) & count_images_in_directory(IMAGES_PATH) == NUMBER_IMGS:
        print(f'Total number of collected images -> {count_images_in_directory(IMAGES_PATH)}')
        break
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Total number of collected images -> 30

# %%
# !labeleme
# Out:
# 'labeleme' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Visualize the dataset and buil image loading function ##

# %% [markdown]
# ### Impor libraries ###

# %%
import tensorflow as tf
import json
import numpy as np
from matplotlib import pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\gavvi\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Load image  into TF data pipeline ###

# %%
images = tf.data.Dataset.list_files('data\\images\\*.jpg', shuffle=False)

# %%
images.as_numpy_iterator().next() # Single image path
# Out:
# b'data\\images\\00cc693a-9023-11ee-94d3-646c8087a76e.jpg'

# %%
def load_image(image_path):
    """
    
    """
    byte_img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(byte_img)
    
    return img

# %%
images = images.map(load_image)

# %%
images.as_numpy_iterator().next() # Actual image
# Out:
# array([[[193, 182, 176],
#         [194, 183, 177],
#         [192, 181, 175],
#         ...,
#         [179, 169, 168],
#         [176, 166, 167],
#         [178, 168, 169]],
#
#        [[195, 184, 178],
#         [195, 184, 178],
#         [194, 183, 177],
#         ...,
#         [181, 171, 170],
#         [176, 166, 167],
#         [177, 167, 168]],
#
#        [[196, 187, 182],
#         [196, 187, 182],
#         [195, 186, 181],
#         ...,
#         [178, 169, 170],
#         [176, 167, 170],
#         [177, 168, 171]],
#
#        ...,
#
#        [[ 49,  73,  83],
#         [ 47,  71,  81],
#         [ 47,  69,  80],
#         ...,
#         [ 25,  25,  35],
#         [ 29,  29,  39],
#         [ 29,  29,  39]],
#
#        [[ 48,  75,  86],
#         [ 45,  72,  81],
#         [ 45,  69,  79],
#         ...,
#         [ 22,  25,  34],
#         [ 25,  28,  37],
#         [ 26,  29,  38]],
#
#        [[ 48,  75,  86],
#         [ 45,  72,  83],
#         [ 45,  69,  79],
#         ...,
#         [ 21,  24,  33],
#         [ 25,  28,  37],
#         [ 26,  29,  38]]], dtype=uint8)

# %%
type(images) # verify the type of our images dataset
# Out:
# tensorflow.python.data.ops.map_op._MapDataset

# %% [markdown]
# ### Visualize raw images using matplotlib ###

# %%
image_generator = images.batch(4).as_numpy_iterator()

# %%
plot_images = image_generator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(plot_images):
    ax[idx].imshow(img)
    ax[idx].axis(False)

plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, *, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, interpolation_stage=None, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %% [markdown]
# ## Partition unagmented data ##

# %%
base_dir = 'data\\'
split_dirs = ['train', 'test', 'val']

# Create directory structure
for split_dir in split_dirs:
    split_path = os.path.join(base_dir, split_dir)
    for subdir in ['images', 'labels']:
        os.makedirs(os.path.join(split_path, subdir), exist_ok=True)

PRINT()
print("Directory structure created successfully.")
PRINT()
# Out:
# --------------------------------------------------------------------------------
# Directory structure created successfully.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Partition unagmented data ##

# %%
def split_data(src_dir, dest_train_dir, dest_val_dir, dest_test_dir, train_ratio=0.7, val_ratio=0.1, test_ratio=0.2):
    # Get the list of all files in the source directory
    all_files = os.listdir(src_dir)
    total_files = len(all_files)

    # Calculate the number of files for each split
    num_train = int(total_files * train_ratio)
    num_val = int(total_files * val_ratio)
    num_test = total_files - num_train - num_val

    # Shuffle the list of files
    random.shuffle(all_files)

    # Split the files into train, validation, and test sets
    train_files = all_files[:num_train]
    val_files = all_files[num_train:num_train + num_val]
    test_files = all_files[num_train + num_val:]

    # Move the files to their respective directories
    move_files(src_dir, dest_train_dir, train_files)
    move_files(src_dir, dest_val_dir, val_files)
    move_files(src_dir, dest_test_dir, test_files)

# %%
def move_files(src_dir, dest_dir, file_list):
    os.makedirs(dest_dir, exist_ok=True)
    for file_name in file_list:
        src_path = os.path.join(src_dir, file_name)
        dest_path = os.path.join(dest_dir, file_name)
        shutil.move(src_path, dest_path)

# %%
src_directory = 'data\\images'
train_directory = 'data\\train\\images'
val_directory = 'data\\val\\images'
test_directory = 'data\\test\\images'

# %%
split_data(src_directory, train_directory, val_directory, test_directory)

# %% [markdown]
# ### Move the matching labels to the correct images folder ###

# %%
for folder in ['train','test','val']:
    for file in os.listdir(os.path.join('data', folder, 'images')):
        
        filename = file.split('.')[0]+'.json'
        existing_filepath = os.path.join('data','labels', filename)
        if os.path.exists(existing_filepath): 
            new_filepath = os.path.join('data',folder,'labels',filename)
            os.replace(existing_filepath, new_filepath)

# %% [markdown]
# ## Apply image augmentation techniques ##

# %%
import albumentations as alb

# %%
augmentor = alb.Compose([
                         alb.HorizontalFlip(p=0.5),
                         alb.RandomGamma(p=0.2),
                         alb.RGBShift(p=0.2),
                         alb.VerticalFlip(p=0.5)],
                        bbox_params=alb.BboxParams(format='albumentations',
                                                   label_fields=['class_labels']))

# %% [markdown]
# ### Test the data augmentation on random image ##

# %%
img = cv2.imread(os.path.join('data','images','00d63fd5-9023-11ee-8490-646c8087a76e.jpg'))

# %%
with open(os.path.join('data','labels','00d63fd5-9023-11ee-8490-646c8087a76e.json'), 'r') as f:
    label = json.load(f)

# %%
type(label)
# Out:
# dict

# %%
label['shapes'][0]['points']
# Out:
# [[85.5654761904762, 8.333333333333334],
#  [222.17261904761904, 172.02380952380955]]

# %% [markdown]
# ### Extract coordinates and rescale to match image resolution ###

# %%
coords = [point for shape in label['shapes'] for points in shape['points'] for point in points]

# %%
PRINT()
print(f"The coordinates of the test image we got are : \n\n{coords}") 
PRINT()
# Out:
# --------------------------------------------------------------------------------
# The coordinates of the test image we got are :
#
# [85.5654761904762, 8.333333333333334, 222.17261904761904, 172.02380952380955]
# --------------------------------------------------------------------------------

# %%
coords = list(np.divide(coords, [640,480,640,480]))

# %%
PRINT()
print(f"The transformed coordinates of the test image we got are : \n\n{coords}") 
PRINT()
# Out:
# --------------------------------------------------------------------------------
# The transformed coordinates of the test image we got are :
#
# [0.13369605654761907, 0.017361111111111112, 0.34714471726190477, 0.35838293650793657]
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Apply augmentation techniques and visualize ###

# %%
augmented = augmentor(image=img, bboxes=[coords], class_labels=['Face'])

# %%
augmented['bboxes'][0][2:]
# Out:
# (0.8663039434523809, 0.35838293650793657)

# %%
cv2.rectangle(augmented['image'], 
              tuple(np.multiply(augmented['bboxes'][0][:2], [250,250]).astype(int)),
              tuple(np.multiply(augmented['bboxes'][0][2:], [250,250]).astype(int)), 
                    (255,0,0), 2)

plt.imshow(augmented['image'])

# %%
for partition in ['train','test','val']: 
    for image in os.listdir(os.path.join('data', partition, 'images')):
        img = cv2.imread(os.path.join('data', partition, 'images', image))

        coords = [0,0,0.00001,0.00001]
        label_path = os.path.join('data', partition, 'labels', f'{image.split(".")[0]}.json')
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)

            coords[0] = label['shapes'][0]['points'][0][0]
            coords[1] = label['shapes'][0]['points'][0][1]
            coords[2] = label['shapes'][0]['points'][1][0]
            coords[3] = label['shapes'][0]['points'][1][1]
            coords = list(np.divide(coords, [640,480,640,480]))

        try: 
            for x in range(60):
                augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
                cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(".")[0]}.{x}.jpg'), augmented['image'])

                annotation = {}
                annotation['image'] = image

                if os.path.exists(label_path):
                    if len(augmented['bboxes']) == 0: 
                        annotation['bbox'] = [0,0,0,0]
                        annotation['class'] = 0 
                    else: 
                        annotation['bbox'] = augmented['bboxes'][0]
                        annotation['class'] = 1
                else: 
                    annotation['bbox'] = [0,0,0,0]
                    annotation['class'] = 0 


                with open(os.path.join('aug_data', partition, 'labels', f'{image.split(".")[0]}.{x}.json'), 'w') as f:
                    json.dump(annotation, f)

        except Exception as e:
            print(e)

# %%
for partition in ['train', 'test', 'val']:
    for image in os.listdir(os.path.join('data', partition, 'images')):
        img = cv2.imread(os.path.join('data', partition, 'images', image))

        label_path = os.path.join('data', partition, 'labels', f'{image.split(".")[0]}.json')
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)

            for face_idx, face in enumerate(label['shapes']):
                coords = [face['points'][0][0], face['points'][0][1], face['points'][1][0], face['points'][1][1]]
                coords = list(np.divide(coords, [640, 480, 640, 480]))

                try:
                    for x in range(60):
                        augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
                        cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(".")[0]}_face{face_idx}_{x}.jpg'), augmented['image'])

                        annotation = {}
                        annotation['image'] = image

                        if len(augmented['bboxes']) == 0:
                            annotation['bbox'] = [0, 0, 0, 0]
                            annotation['class'] = 0
                        else:
                            annotation['bbox'] = augmented['bboxes'][0]
                            annotation['class'] = 1

                        with open(os.path.join('aug_data', partition, 'labels', f'{image.split(".")[0]}_face{face_idx}_{x}.json'), 'w') as f:
                            json.dump(annotation, f)

                except Exception as e:
                    print(e)
# Out:
# Expected x_min for bbox [1.2748991935483869, 3.088575268817204, 1.3807459677419351, 3.216263440860215, 'face'] to be in the range [0.0, 1.0], got 1.2748991935483869.
# Expected x_min for bbox [1.400907258064516, 3.0079301075268816, 1.5168346774193544, 3.135618279569892, 'face'] to be in the range [0.0, 1.0], got 1.400907258064516.
# Expected x_min for bbox [4.273891129032258, 4.365456989247312, 4.667036290322581, 4.82244623655914, 'face'] to be in the range [0.0, 1.0], got 4.273891129032258.
# Expected x_min for bbox [2.3650815217391306, 3.233876811594203, 2.8066576086956525, 3.8317028985507244, 'face'] to be in the range [0.0, 1.0], got 2.3650815217391306.
# Expected x_min for bbox [2.4805706521739133, 3.2429347826086956, 2.956114130434783, 3.704891304347826, 'face'] to be in the range [0.0, 1.0], got 2.4805706521739133.
# Expected x_min for bbox [2.2767663043478263, 4.184963768115941, 2.5077445652173913, 4.43858695652174, 'face'] to be in the range [0.0, 1.0], got 2.2767663043478263.
# Expected y_min for bbox [0.184375, 4.284601449275362, 0.4221467391304351, 4.583514492753623, 'face'] to be in the range [0.0, 1.0], got 4.284601449275362.
# Expected x_min for bbox [1.108288043478261, 3.6958333333333333, 1.3256793478260875, 3.9766304347826087, 'face'] to be in the range [0.0, 1.0], got 1.108288043478261.
# Expected x_min for bbox [1.644972826086957, 3.7139492753623187, 1.9778532608695656, 3.9766304347826087, 'face'] to be in the range [0.0, 1.0], got 1.644972826086957.
# Expected x_min for bbox [2.725135869565217, 3.6143115942028983, 2.9221467391304343, 3.8769927536231887, 'face'] to be in the range [0.0, 1.0], got 2.725135869565217.
# Expected x_min for bbox [2.371875, 3.7139492753623187, 2.562092391304348, 3.8769927536231887, 'face'] to be in the range [0.0, 1.0], got 2.371875.
# Expected x_min for bbox [2.0525815217391306, 3.759239130434783, 2.202038043478261, 3.922282608695652, 'face'] to be in the range [0.0, 1.0], got 2.0525815217391306.
# Expected y_min for bbox [0.019858870967741638, 2.0939516129032256, 0.6347782258064513, 3.1826612903225806, 'face'] to be in the range [0.0, 1.0], got 2.0939516129032256.
# Expected x_min for bbox [2.4039314516129027, 2.3896505376344086, 2.540020161290322, 2.571102150537634, 'face'] to be in the range [0.0, 1.0], got 2.4039314516129027.
# Expected x_min for bbox [3.6337701612903217, 2.503897849462365, 3.764818548387096, 2.6719086021505376, 'face'] to be in the range [0.0, 1.0], got 3.6337701612903217.
# Expected x_min for bbox [1.7808423913043476, 1.920471014492754, 2.2631793478260867, 2.4639492753623187, 'face'] to be in the range [0.0, 1.0], got 1.7808423913043476.
# Expected x_min for bbox [1.7264945652173913, 3.0617753623188406, 2.5756793478260867, 4.2574275362318845, 'face'] to be in the range [0.0, 1.0], got 1.7264945652173913.
# Expected x_min for bbox [1.5928385416666664, 0.9564236111111112, 3.324609375, 3.621354166666667, 'face'] to be in the range [0.0, 1.0], got 1.5928385416666664.
# Expected x_min for bbox [3.6501302083333336, 0.6092013888888891, 4.6527343750000005, 2.8227430555555557, 'face'] to be in the range [0.0, 1.0], got 3.6501302083333336.
# Expected x_min for bbox [4.743880208333334, 2.9355902777777776, 6.2738281250000005, 5.461631944444445, 'face'] to be in the range [0.0, 1.0], got 4.743880208333334.
# Expected x_min for bbox [5.811588541666667, 1.9286458333333336, 6.065494791666667, 2.1890625, 'face'] to be in the range [0.0, 1.0], got 5.811588541666667.
# Expected x_min for bbox [6.0980468750000005, 1.9546875000000001, 6.345442708333334, 2.293229166666667, 'face'] to be in the range [0.0, 1.0], got 6.0980468750000005.
# Expected y_min for bbox [0.9287760416666664, 2.3453125, 1.351953125, 2.7793402777777776, 'face'] to be in the range [0.0, 1.0], got 2.3453125.
# Expected y_min for bbox [0.14752604166666644, 2.3105902777777776, 0.25169270833333324, 2.449479166666667, 'face'] to be in the range [0.0, 1.0], got 2.3105902777777776.
# Expected y_min for bbox [0.043359375, 2.909548611111111, 0.9938802083333332, 4.098784722222223, 'face'] to be in the range [0.0, 1.0], got 2.909548611111111.
# Expected x_min for bbox [1.5901041666666669, 1.1451388888888887, 2.777604166666667, 2.7354166666666666, 'face'] to be in the range [0.0, 1.0], got 1.5901041666666669.
# Expected x_min for bbox [2.0015625000000004, 2.8743055555555554, 2.9755208333333334, 3.777083333333333, 'face'] to be in the range [0.0, 1.0], got 2.0015625000000004.
# Expected y_min for bbox [0.6994791666666668, 3.853472222222222, 2.0796875000000004, 5.263194444444445, 'face'] to be in the range [0.0, 1.0], got 3.853472222222222.
# Expected x_min for bbox [2.261979166666667, 4.728472222222222, 2.4390625000000004, 4.915972222222222, 'face'] to be in the range [0.0, 1.0], got 2.261979166666667.
# Expected x_min for bbox [2.2359375000000004, 4.978472222222222, 2.4286458333333334, 5.165972222222222, 'face'] to be in the range [0.0, 1.0], got 2.2359375000000004.
# Expected x_min for bbox [2.0223958333333334, 0.7493055555555553, 2.246354166666667, 1.0965277777777778, 'face'] to be in the range [0.0, 1.0], got 2.0223958333333334.
# Expected x_min for bbox [1.3713541666666669, 0.027083333333333178, 1.9911458333333332, 0.8256944444444443, 'face'] to be in the range [0.0, 1.0], got 1.3713541666666669.
# Expected x_min for bbox [2.8677989130434782, 5.009239130434782, 3.2754076086956516, 5.634239130434782, 'face'] to be in the range [0.0, 1.0], got 2.8677989130434782.
# Expected x_min for bbox [3.3705163043478263, 4.782789855072464, 3.7441576086956516, 5.280978260869565, 'face'] to be in the range [0.0, 1.0], got 3.3705163043478263.
# Expected y_min for bbox [0.3542119565217391, 4.692210144927537, 0.7346467391304351, 5.181340579710144, 'face'] to be in the range [0.0, 1.0], got 4.692210144927537.
# Expected y_min for bbox [0.6938858695652179, 4.293659420289855, 1.019972826086957, 4.7375, 'face'] to be in the range [0.0, 1.0], got 4.293659420289855.
# Expected y_min for bbox [0.7686141304347828, 4.8280797101449275, 1.189809782608696, 5.280978260869565, 'face'] to be in the range [0.0, 1.0], got 4.8280797101449275.
# Expected x_min for bbox [3.1055706521739124, 4.230253623188406, 3.3841032608695656, 4.4023550724637674, 'face'] to be in the range [0.0, 1.0], got 3.1055706521739124.
# Expected x_min for bbox [3.8120923913043483, 4.529166666666667, 4.144972826086956, 4.90054347826087, 'face'] to be in the range [0.0, 1.0], got 3.8120923913043483.
# Expected x_min for bbox [3.085190217391305, 4.511050724637681, 3.778125, 5.1903985507246375, 'face'] to be in the range [0.0, 1.0], got 3.085190217391305.
# Expected x_min for bbox [1.4139945652173913, 2.96213768115942, 2.0118206521739133, 3.6867753623188406, 'face'] to be in the range [0.0, 1.0], got 1.4139945652173913.
# Expected y_min for bbox [0.03491847826086954, 3.7954710144927537, 0.31345108695652185, 4.1125, 'face'] to be in the range [0.0, 1.0], got 3.7954710144927537.
# Expected y_min for bbox [0.21834239130434838, 4.809963768115941, 0.7278532608695656, 5.46213768115942, 'face'] to be in the range [0.0, 1.0], got 4.809963768115941.
# Expected x_max for bbox [0.3813858695652172, 0.11340579710144963, 1.7061141304347829, 1.5445652173913047, 'face'] to be in the range [0.0, 1.0], got 1.7061141304347829.
# Expected x_min for bbox [1.4819293478260867, 2.921376811594203, 1.6449728260869563, 3.175, 'face'] to be in the range [0.0, 1.0], got 1.4819293478260867.
# Expected x_min for bbox [2.093342391304348, 2.5318840579710145, 2.2631793478260867, 2.767391304347826, 'face'] to be in the range [0.0, 1.0], got 2.093342391304348.
# Expected y_min for bbox [0.7822010869565219, 2.622463768115942, 1.2169836956521736, 3.2384057971014495, 'face'] to be in the range [0.0, 1.0], got 2.622463768115942.
# Expected x_min for bbox [1.3256793478260867, 3.9268115942028983, 1.4683423913043476, 4.098913043478261, 'face'] to be in the range [0.0, 1.0], got 1.3256793478260867.
# Expected y_min for bbox [0.46970108695652185, 2.115217391304348, 0.585190217391304, 2.2510869565217395, 'face'] to be in the range [0.0, 1.0], got 2.115217391304348.
# Expected x_min for bbox [1.3256793478260867, 2.1061594202898553, 1.4819293478260867, 2.269202898550725, 'face'] to be in the range [0.0, 1.0], got 1.3256793478260867.
# Expected x_min for bbox [3.424864130434783, 1.9884057971014495, 3.5267663043478263, 2.115217391304348, 'face'] to be in the range [0.0, 1.0], got 3.424864130434783.
# Expected x_min for bbox [2.7523097826086955, 1.861594202898551, 2.8949728260869563, 2.196739130434783, 'face'] to be in the range [0.0, 1.0], got 2.7523097826086955.
# Expected x_min for bbox [1.5498641304347829, 1.0463768115942031, 1.7876358695652173, 1.2909420289855076, 'face'] to be in the range [0.0, 1.0], got 1.5498641304347829.
# Expected y_min for bbox [0.5783967391304344, 1.5445652173913047, 0.8297554347826086, 1.8525362318840581, 'face'] to be in the range [0.0, 1.0], got 1.5445652173913047.
# Expected x_min for bbox [1.8555706521739126, 3.328985507246377, 2.045788043478261, 3.5554347826086956, 'face'] to be in the range [0.0, 1.0], got 1.8555706521739126.
# Expected x_min for bbox [2.8881793478260867, 3.4557971014492757, 3.397690217391305, 4.008333333333334, 'face'] to be in the range [0.0, 1.0], got 2.8881793478260867.
# Expected y_min for bbox [0.014538043478260931, 3.6460144927536233, 0.3474184782608695, 4.488405797101449, 'face'] to be in the range [0.0, 1.0], got 3.6460144927536233.
# Expected x_min for bbox [2.6639945652173913, 3.4195652173913045, 2.8338315217391306, 3.7275362318840584, 'face'] to be in the range [0.0, 1.0], got 2.6639945652173913.
# Expected x_min for bbox [2.1341032608695647, 1.6170289855072466, 2.772690217391304, 2.3144927536231887, 'face'] to be in the range [0.0, 1.0], got 2.1341032608695647.
# Expected x_min for bbox [1.5974184782608696, 1.164130434782609, 2.3922554347826086, 2.2148550724637683, 'face'] to be in the range [0.0, 1.0], got 1.5974184782608696.
# Expected x_min for bbox [2.5609375, 4.044444444444444, 2.6807291666666666, 4.183333333333334, 'face'] to be in the range [0.0, 1.0], got 2.5609375.
# Expected x_min for bbox [2.0244791666666666, 4.113888888888889, 2.1078125, 4.231944444444445, 'face'] to be in the range [0.0, 1.0], got 2.0244791666666666.
# Expected y_min for bbox [0.9932291666666663, 3.9125, 1.1026041666666662, 4.051388888888889, 'face'] to be in the range [0.0, 1.0], got 3.9125.
# Expected x_min for bbox [1.1807291666666662, 3.947222222222222, 1.2848958333333331, 4.127777777777777, 'face'] to be in the range [0.0, 1.0], got 1.1807291666666662.
# Expected x_min for bbox [2.1494791666666666, 4.197222222222222, 2.2901041666666666, 4.322222222222222, 'face'] to be in the range [0.0, 1.0], got 2.1494791666666666.
# Expected x_min for bbox [2.5661458333333336, 3.961111111111111, 2.7432291666666666, 4.141666666666667, 'face'] to be in the range [0.0, 1.0], got 2.5661458333333336.
# Expected x_min for bbox [3.7432291666666666, 3.85, 3.8473958333333336, 4.002777777777777, 'face'] to be in the range [0.0, 1.0], got 3.7432291666666666.
# Expected y_min for bbox [0.13385416666666625, 4.086111111111111, 0.2640624999999998, 4.231944444444445, 'face'] to be in the range [0.0, 1.0], got 4.086111111111111.
# Expected x_min for bbox [2.7115489130434782, 3.1568840579710145, 2.8677989130434782, 3.33804347826087, 'face'] to be in the range [0.0, 1.0], got 2.7115489130434782.
# Expected y_min for bbox [0.5716032608695649, 2.9032608695652176, 0.8433423913043476, 3.310869565217392, 'face'] to be in the range [0.0, 1.0], got 2.9032608695652176.
# Expected x_min for bbox [3.2618206521739124, 1.0282608695652178, 3.7033967391304343, 1.5083333333333335, 'face'] to be in the range [0.0, 1.0], got 3.2618206521739124.
# Expected x_min for bbox [2.317527173913043, 1.8253623188405799, 2.514538043478261, 1.9974637681159422, 'face'] to be in the range [0.0, 1.0], got 2.317527173913043.
# Expected y_min for bbox [0.7346467391304344, 1.8163043478260872, 0.9180706521739133, 2.0246376811594207, 'face'] to be in the range [0.0, 1.0], got 1.8163043478260872.
# Expected y_min for bbox [0.014538043478260931, 2.7311594202898553, 0.5308423913043476, 3.1478260869565218, 'face'] to be in the range [0.0, 1.0], got 2.7311594202898553.
# Expected x_min for bbox [1.278125, 1.8797101449275364, 1.434375, 2.0699275362318845, 'face'] to be in the range [0.0, 1.0], got 1.278125.
# Expected x_min for bbox [1.2033967391304343, 1.789130434782609, 1.3460597826086953, 1.9702898550724641, 'face'] to be in the range [0.0, 1.0], got 1.2033967391304343.
# Expected x_min for bbox [1.1898097826086953, 1.707608695652174, 1.7808423913043476, 2.658695652173913, 'face'] to be in the range [0.0, 1.0], got 1.1898097826086953.
# Expected y_max for bbox [0.3202445652173914, 0.17681159420289888, 0.7957880434782609, 1.091666666666667, 'face'] to be in the range [0.0, 1.0], got 1.091666666666667.
# Expected x_min for bbox [3.3841032608695656, 0.2673913043478264, 3.5267663043478263, 0.502898550724638, 'face'] to be in the range [0.0, 1.0], got 3.3841032608695656.
# Expected x_min for bbox [4.090625, 0.28550724637681196, 4.2734375, 0.48723138430784657, 'face'] to be in the range [0.0, 1.0], got 4.090625.
# Expected x_min for bbox [1.1014945652173913, 1.7981884057971016, 1.577038043478261, 2.540942028985507, 'face'] to be in the range [0.0, 1.0], got 1.1014945652173913.
# [Errno 2] No such file or directory: 'aug_data\\train\\labels\\IMG_20190812_164223_face1_0.json'
# Expected x_max for bbox [0.8229619565217391, 0.14057971014492787, 1.1014945652173913, 0.37608695652173946, 'face'] to be in the range [0.0, 1.0], got 1.1014945652173913.
# Expected x_min for bbox [3.553940217391305, 0.02282608695652209, 3.7305706521739124, 0.14963768115942064, 'face'] to be in the range [0.0, 1.0], got 3.553940217391305.
# Expected x_min for bbox [1.4275815217391306, 1.4721014492753626, 1.977853260869565, 2.3960144927536233, 'face'] to be in the range [0.0, 1.0], got 1.4275815217391306.
# Expected x_min for bbox [3.662635869565217, 1.2909420289855076, 3.8868206521739124, 1.5717391304347827, 'face'] to be in the range [0.0, 1.0], got 3.662635869565217.
# Expected x_max for bbox [0.48328804347826093, 0.14963768115942064, 1.0131793478260867, 0.8652173913043482, 'face'] to be in the range [0.0, 1.0], got 1.0131793478260867.
# Expected y_min for bbox [0.7686141304347828, 1.3181159420289856, 0.9316576086956523, 1.5717391304347827, 'face'] to be in the range [0.0, 1.0], got 1.3181159420289856.
# Expected y_max for bbox [0.04171195652173907, 0.3217391304347829, 0.5716032608695649, 1.281884057971015, 'face'] to be in the range [0.0, 1.0], got 1.281884057971015.
# Expected x_min for bbox [1.6585597826086953, 6.010144927536232, 1.916711956521739, 6.272826086956522, 'face'] to be in the range [0.0, 1.0], got 1.6585597826086953.
# Expected x_min for bbox [2.1680706521739124, 5.9195652173913045, 2.371875, 6.100724637681159, 'face'] to be in the range [0.0, 1.0], got 2.1680706521739124.
# Expected x_min for bbox [2.514538043478261, 6.173188405797101, 2.7658967391304343, 6.472101449275362, 'face'] to be in the range [0.0, 1.0], got 2.514538043478261.
# Expected x_min for bbox [1.434375, 3.627898550724638, 1.590625, 3.845289855072464, 'face'] to be in the range [0.0, 1.0], got 1.434375.
# Expected x_min for bbox [1.916711956521739, 3.7456521739130437, 2.1069293478260867, 4.053623188405798, 'face'] to be in the range [0.0, 1.0], got 1.916711956521739.
# Expected y_min for bbox [0.897690217391304, 3.609782608695652, 1.108288043478261, 3.7547101449275364, 'face'] to be in the range [0.0, 1.0], got 3.609782608695652.
# Expected y_min for bbox [0.8161684782608696, 4.162318840579711, 1.1762228260869563, 4.551811594202899, 'face'] to be in the range [0.0, 1.0], got 4.162318840579711.
# Expected y_min for bbox [0.2047554347826086, 3.627898550724638, 0.46290760869565234, 3.881521739130435, 'face'] to be in the range [0.0, 1.0], got 3.627898550724638.
# Expected x_min for bbox [2.3379076086956525, 3.7184782608695652, 2.4669836956521736, 3.8905797101449275, 'face'] to be in the range [0.0, 1.0], got 2.3379076086956525.
# Expected x_min for bbox [2.589266304347826, 3.6731884057971014, 2.697961956521739, 3.7728260869565218, 'face'] to be in the range [0.0, 1.0], got 2.589266304347826.
# Expected y_min for bbox [0.5308423913043476, 3.582608695652174, 0.7142663043478258, 3.8090579710144925, 'face'] to be in the range [0.0, 1.0], got 3.582608695652174.
# Expected x_min for bbox [1.9982336956521736, 5.203985507246377, 2.3447010869565217, 5.647826086956522, 'face'] to be in the range [0.0, 1.0], got 1.9982336956521736.
# Expected x_min for bbox [1.563451086956522, 5.37608695652174, 1.7061141304347829, 5.521014492753623, 'face'] to be in the range [0.0, 1.0], got 1.563451086956522.
# Expected x_min for bbox [2.059375, 4.75108695652174, 2.174864130434782, 4.923188405797101, 'face'] to be in the range [0.0, 1.0], got 2.059375.
# Expected x_min for bbox [3.669429347826086, 6.571739130434782, 3.968342391304347, 7.02463768115942, 'face'] to be in the range [0.0, 1.0], got 3.669429347826086.
# Expected x_min for bbox [2.697961956521739, 6.852536231884058, 3.044429347826086, 7.1695652173913045, 'face'] to be in the range [0.0, 1.0], got 2.697961956521739.
# Expected x_min for bbox [2.6232336956521736, 5.530072463768116, 2.8134510869565217, 5.783695652173914, 'face'] to be in the range [0.0, 1.0], got 2.6232336956521736.
# Expected x_min for bbox [2.331114130434782, 5.511956521739131, 2.528125, 5.747463768115941, 'face'] to be in the range [0.0, 1.0], got 2.331114130434782.
# Expected x_min for bbox [1.7129076086956523, 5.385144927536232, 1.9099184782608696, 5.602536231884058, 'face'] to be in the range [0.0, 1.0], got 1.7129076086956523.
# Expected y_min for bbox [0.6870923913043476, 5.584420289855073, 0.7957880434782609, 5.720289855072464, 'face'] to be in the range [0.0, 1.0], got 5.584420289855073.
# Expected y_min for bbox [0.9588315217391304, 5.457608695652174, 1.094701086956522, 5.602536231884058, 'face'] to be in the range [0.0, 1.0], got 5.457608695652174.
# Expected x_min for bbox [1.339266304347826, 5.3398550724637674, 1.434375, 5.475724637681159, 'face'] to be in the range [0.0, 1.0], got 1.339266304347826.
# Expected x_min for bbox [3.3773097826086955, 5.167753623188406, 3.479211956521739, 5.321739130434782, 'face'] to be in the range [0.0, 1.0], got 3.3773097826086955.
# Expected x_min for bbox [3.934375, 5.31268115942029, 4.063451086956522, 5.5028985507246375, 'face'] to be in the range [0.0, 1.0], got 3.934375.
# Expected y_min for bbox [0.19796195652173906, 5.521014492753623, 0.30665760869565234, 5.702173913043478, 'face'] to be in the range [0.0, 1.0], got 5.521014492753623.
# Expected y_min for bbox [0.6599184782608696, 3.3742753623188406, 1.1694293478260867, 3.9811594202898553, 'face'] to be in the range [0.0, 1.0], got 3.3742753623188406.
# Expected x_min for bbox [1.577038043478261, 2.486594202898551, 2.4262228260869563, 3.1931159420289856, 'face'] to be in the range [0.0, 1.0], got 1.577038043478261.
# Expected x_min for bbox [2.4941576086956525, 3.0210144927536233, 2.6639945652173913, 3.310869565217392, 'face'] to be in the range [0.0, 1.0], got 2.4941576086956525.
# Expected x_min for bbox [3.934375, 2.9938405797101453, 4.199320652173912, 3.3561594202898553, 'face'] to be in the range [0.0, 1.0], got 3.934375.
# Expected y_min for bbox [0.44932065217391326, 3.2112318840579714, 0.6870923913043476, 3.519202898550725, 'face'] to be in the range [0.0, 1.0], got 3.2112318840579714.
# Expected y_min for bbox [0.03491847826086954, 3.1206521739130437, 0.26589673913043443, 3.3471014492753626, 'face'] to be in the range [0.0, 1.0], got 3.1206521739130437.
# Expected x_min for bbox [2.8134510869565217, 3.229347826086957, 3.010461956521739, 3.3742753623188406, 'face'] to be in the range [0.0, 1.0], got 2.8134510869565217.
# Expected x_min for bbox [3.0580163043478263, 3.066304347826087, 3.153125, 3.229347826086957, 'face'] to be in the range [0.0, 1.0], got 3.0580163043478263.
# Expected x_min for bbox [1.434375, 3.3471014492753626, 1.9438858695652173, 3.953985507246377, 'face'] to be in the range [0.0, 1.0], got 1.434375.
# Expected x_min for bbox [3.4860054347826077, 3.5282608695652176, 3.812092391304347, 3.89963768115942, 'face'] to be in the range [0.0, 1.0], got 3.4860054347826077.
# Expected y_min for bbox [0.5240489130434781, 3.763768115942029, 0.6327445652173914, 3.935869565217392, 'face'] to be in the range [0.0, 1.0], got 3.763768115942029.
# Expected y_min for bbox [0.028125, 4.026449275362319, 0.7006793478260868, 5.176811594202899, 'face'] to be in the range [0.0, 1.0], got 4.026449275362319.
# Expected x_min for bbox [2.5756793478260867, 3.591666666666667, 2.6639945652173913, 3.70036231884058, 'face'] to be in the range [0.0, 1.0], got 2.5756793478260867.
# Expected x_min for bbox [3.7640625, 3.5791666666666666, 3.9776041666666666, 3.7875, 'face'] to be in the range [0.0, 1.0], got 3.7640625.
# Expected x_min for bbox [3.3942708333333336, 3.461111111111111, 3.5036458333333336, 3.6138888888888885, 'face'] to be in the range [0.0, 1.0], got 3.3942708333333336.
# Expected x_min for bbox [3.6911458333333336, 3.4819444444444443, 3.7744791666666666, 3.558333333333333, 'face'] to be in the range [0.0, 1.0], got 3.6911458333333336.
# Expected x_min for bbox [2.215625, 3.582608695652174, 2.358288043478261, 3.763768115942029, 'face'] to be in the range [0.0, 1.0], got 2.215625.
# Expected x_min for bbox [1.590625, 2.5318840579710145, 2.3514945652173913, 3.5554347826086956, 'face'] to be in the range [0.0, 1.0], got 1.590625.
# Expected x_min for bbox [1.5348958333333331, 1.5375, 2.3890625, 2.7041666666666666, 'face'] to be in the range [0.0, 1.0], got 1.5348958333333331.
# Expected x_min for bbox [1.5140624999999999, 1.6, 2.4776041666666666, 2.773611111111111, 'face'] to be in the range [0.0, 1.0], got 1.5140624999999999.
# Expected x_min for bbox [1.4567708333333331, 1.5583333333333333, 2.3942708333333336, 2.773611111111111, 'face'] to be in the range [0.0, 1.0], got 1.4567708333333331.
# Expected x_min for bbox [3.5505208333333336, 2.398611111111111, 3.9567708333333336, 3.0375, 'face'] to be in the range [0.0, 1.0], got 3.5505208333333336.
# Expected x_min for bbox [4.613020833333334, 2.1694444444444443, 4.946354166666667, 2.822222222222222, 'face'] to be in the range [0.0, 1.0], got 4.613020833333334.
# Expected x_min for bbox [3.4776041666666666, 2.495833333333333, 4.0140625, 3.120833333333333, 'face'] to be in the range [0.0, 1.0], got 3.4776041666666666.
# Expected x_min for bbox [4.519270833333334, 2.4263888888888885, 4.956770833333334, 2.884722222222222, 'face'] to be in the range [0.0, 1.0], got 4.519270833333334.
# Expected x_min for bbox [3.5609375, 2.433333333333333, 4.102604166666667, 3.1069444444444443, 'face'] to be in the range [0.0, 1.0], got 3.5609375.
# Expected x_min for bbox [4.628645833333334, 2.3152777777777778, 5.024479166666667, 2.808333333333333, 'face'] to be in the range [0.0, 1.0], got 4.628645833333334.
# Expected x_min for bbox [2.6598958333333336, 2.308333333333333, 3.1078125, 2.9402777777777778, 'face'] to be in the range [0.0, 1.0], got 2.6598958333333336.
# Expected x_min for bbox [5.128645833333334, 2.1694444444444443, 5.555729166666667, 2.7666666666666666, 'face'] to be in the range [0.0, 1.0], got 5.128645833333334.
# Expected x_min for bbox [2.7692708333333336, 1.8430555555555554, 3.1859375, 2.495833333333333, 'face'] to be in the range [0.0, 1.0], got 2.7692708333333336.
# Expected x_min for bbox [5.2640625000000005, 1.7805555555555554, 5.602604166666667, 2.447222222222222, 'face'] to be in the range [0.0, 1.0], got 5.2640625000000005.
# Expected x_min for bbox [2.7171875, 1.8708333333333333, 3.1598958333333336, 2.572222222222222, 'face'] to be in the range [0.0, 1.0], got 2.7171875.
# Expected x_min for bbox [5.300520833333334, 1.8013888888888887, 5.633854166666667, 2.4888888888888885, 'face'] to be in the range [0.0, 1.0], got 5.300520833333334.
# Expected x_min for bbox [5.097395833333334, 2.113888888888889, 5.3578125000000005, 2.3013888888888885, 'face'] to be in the range [0.0, 1.0], got 5.097395833333334.
# Expected x_min for bbox [3.0348958333333336, 1.8222222222222222, 3.3838541666666666, 2.4541666666666666, 'face'] to be in the range [0.0, 1.0], got 3.0348958333333336.
# Expected x_min for bbox [4.909895833333334, 2.113888888888889, 5.274479166666667, 2.509722222222222, 'face'] to be in the range [0.0, 1.0], got 4.909895833333334.
# Expected x_min for bbox [5.305729166666667, 2.0444444444444447, 5.649479166666667, 2.8638888888888885, 'face'] to be in the range [0.0, 1.0], got 5.305729166666667.
# Expected x_min for bbox [3.343342391304347, 1.1731884057971018, 3.941168478260869, 1.9250000000000003, 'face'] to be in the range [0.0, 1.0], got 3.343342391304347.
# Expected y_max for bbox [0.7006793478260868, 0.9467391304347831, 0.9044836956521735, 1.5717391304347827, 'face'] to be in the range [0.0, 1.0], got 1.5717391304347827.
# Expected x_min for bbox [1.5702445652173913, 0.8289855072463772, 2.630027173913043, 2.7311594202898553, 'face'] to be in the range [0.0, 1.0], got 1.5702445652173913.
# Expected x_min for bbox [2.018614130434782, 1.082608695652174, 2.670788043478261, 2.2148550724637683, 'face'] to be in the range [0.0, 1.0], got 2.018614130434782.
# Expected x_min for bbox [3.309375, 1.6623188405797105, 3.778125, 2.3960144927536233, 'face'] to be in the range [0.0, 1.0], got 3.309375.
# Expected x_min for bbox [1.3188858695652173, 0.7927536231884063, 1.8623641304347829, 1.6804347826086958, 'face'] to be in the range [0.0, 1.0], got 1.3188858695652173.
# Expected x_min for bbox [2.317527173913043, 0.3670289855072467, 2.697961956521739, 1.0101449275362322, 'face'] to be in the range [0.0, 1.0], got 2.317527173913043.
# Expected x_min for bbox [3.2482336956521736, 1.0644927536231887, 3.465625, 1.4902173913043482, 'face'] to be in the range [0.0, 1.0], got 3.2482336956521736.
# Expected y_min for bbox [0.26589673913043443, 1.8434782608695655, 0.6055706521739133, 2.332608695652174, 'face'] to be in the range [0.0, 1.0], got 1.8434782608695655.
# Expected x_min for bbox [1.067527173913043, 1.8978260869565218, 1.3120923913043476, 2.2420289855072464, 'face'] to be in the range [0.0, 1.0], got 1.067527173913043.
# Expected x_min for bbox [2.514538043478261, 0.7384057971014497, 3.159918478260869, 1.8525362318840581, 'face'] to be in the range [0.0, 1.0], got 2.514538043478261.
# Expected x_min for bbox [4.015896739130435, 1.6532608695652178, 4.2734375, 2.2489333776989056, 'face'] to be in the range [0.0, 1.0], got 4.015896739130435.
# Expected x_min for bbox [3.968342391304347, 0.874275362318841, 4.2734375, 1.339182194616978, 'face'] to be in the range [0.0, 1.0], got 3.968342391304347.
# Expected x_min for bbox [3.288994565217391, 0.18586956521739165, 3.6490489130434782, 0.8199275362318844, 'face'] to be in the range [0.0, 1.0], got 3.288994565217391.
# Expected x_min for bbox [2.9900815217391297, 0.502898550724638, 3.397690217391305, 1.236594202898551, 'face'] to be in the range [0.0, 1.0], got 2.9900815217391297.
# Expected y_min for bbox [0.5716032608695649, 2.1061594202898553, 0.9384510869565219, 2.568115942028986, 'face'] to be in the range [0.0, 1.0], got 2.1061594202898553.
# Expected x_min for bbox [1.651766304347826, 2.223913043478261, 1.9099184782608696, 2.622463768115942, 'face'] to be in the range [0.0, 1.0], got 1.651766304347826.
# Expected y_min for bbox [0.8637228260869563, 2.45036231884058, 1.210190217391304, 2.9485507246376814, 'face'] to be in the range [0.0, 1.0], got 2.45036231884058.
# Expected x_min for bbox [1.278125, 2.2148550724637683, 1.5430706521739126, 2.6134057971014495, 'face'] to be in the range [0.0, 1.0], got 1.278125.
# Expected x_min for bbox [2.1069293478260867, 1.1550724637681162, 2.725135869565217, 2.223913043478261, 'face'] to be in the range [0.0, 1.0], got 2.1069293478260867.
# Expected x_min for bbox [2.9629076086956516, 0.9739130434782612, 3.316168478260869, 1.752898550724638, 'face'] to be in the range [0.0, 1.0], got 2.9629076086956516.
# Expected x_min for bbox [3.635461956521739, 0.7384057971014497, 3.9955163043478263, 1.4721014492753626, 'face'] to be in the range [0.0, 1.0], got 3.635461956521739.
# Expected x_min for bbox [4.077038043478261, 1.888768115942029, 4.2734375, 2.6862689393939396, 'face'] to be in the range [0.0, 1.0], got 4.077038043478261.
# Expected y_min for bbox [0.25910326086956487, 2.776449275362319, 0.6463315217391304, 3.3561594202898553, 'face'] to be in the range [0.0, 1.0], got 2.776449275362319.
# Expected x_min for bbox [1.4751358695652173, 2.740217391304348, 1.746875, 3.0481884057971014, 'face'] to be in the range [0.0, 1.0], got 1.4751358695652173.
# Expected x_min for bbox [2.589266304347826, 2.957608695652174, 2.8474184782608694, 3.27463768115942, 'face'] to be in the range [0.0, 1.0], got 2.589266304347826.
# Expected x_min for bbox [2.9697010869565217, 2.5318840579710145, 3.1191576086956516, 2.7311594202898553, 'face'] to be in the range [0.0, 1.0], got 2.9697010869565217.
# Expected x_min for bbox [2.5196180555555565, 2.310416666666667, 4.403298611111112, 6.349768518518519, 'face'] to be in the range [0.0, 1.0], got 2.5196180555555565.
# Expected x_min for bbox [1.5733072916666668, 2.1239583333333334, 2.771223958333333, 4.311458333333334, 'face'] to be in the range [0.0, 1.0], got 1.5733072916666668.
# Expected x_min for bbox [3.0707031250000005, 0.7090277777777778, 4.750390625, 3.582291666666667, 'face'] to be in the range [0.0, 1.0], got 3.0707031250000005.
# Expected x_min for bbox [3.1911458333333336, 1.1972222222222222, 3.6494791666666666, 2.0930555555555554, 'face'] to be in the range [0.0, 1.0], got 3.1911458333333336.
# Expected x_min for bbox [3.8682291666666666, 1.3291666666666666, 4.321354166666667, 2.1208333333333336, 'face'] to be in the range [0.0, 1.0], got 3.8682291666666666.
# Expected x_min for bbox [5.300520833333334, 0.6416666666666665, 5.378645833333334, 0.7527777777777777, 'face'] to be in the range [0.0, 1.0], got 5.300520833333334.
# Expected x_min for bbox [2.4359375, 1.4402777777777778, 2.9203125, 2.245833333333333, 'face'] to be in the range [0.0, 1.0], got 2.4359375.
# Expected x_min for bbox [3.0765625, 1.5305555555555554, 3.4880208333333336, 2.3013888888888885, 'face'] to be in the range [0.0, 1.0], got 3.0765625.
# Expected x_min for bbox [4.3578125, 0.9194444444444443, 4.4359375, 0.9819444444444443, 'face'] to be in the range [0.0, 1.0], got 4.3578125.
# Expected x_min for bbox [2.5401041666666666, 1.2805555555555554, 3.0140625, 2.2527777777777778, 'face'] to be in the range [0.0, 1.0], got 2.5401041666666666.
# Expected x_min for bbox [3.1807291666666666, 1.5027777777777778, 3.6130208333333336, 2.1902777777777778, 'face'] to be in the range [0.0, 1.0], got 3.1807291666666666.
# Expected x_min for bbox [4.508854166666667, 0.8499999999999999, 4.5921875, 0.9402777777777777, 'face'] to be in the range [0.0, 1.0], got 4.508854166666667.
# Expected y_min for bbox [0.897690217391304, 1.4358695652173916, 1.2169836956521736, 1.7710144927536233, 'face'] to be in the range [0.0, 1.0], got 1.4358695652173916.
# Expected x_min for bbox [2.9221467391304343, 4.234782608695652, 3.085190217391305, 4.515579710144928, 'face'] to be in the range [0.0, 1.0], got 2.9221467391304343.
# Expected x_min for bbox [1.3936141304347829, 4.298188405797101, 1.665353260869565, 4.732971014492754, 'face'] to be in the range [0.0, 1.0], got 1.3936141304347829.
# Expected y_min for bbox [0.27948369565217346, 4.425, 0.49008152173913044, 4.6695652173913045, 'face'] to be in the range [0.0, 1.0], got 4.425.
# Expected x_min for bbox [1.2373641304347829, 4.180434782608696, 1.3732336956521736, 4.4068840579710145, 'face'] to be in the range [0.0, 1.0], got 1.2373641304347829.
# Expected x_min for bbox [2.6911458333333336, 1.6902777777777778, 3.1182291666666666, 2.2180555555555554, 'face'] to be in the range [0.0, 1.0], got 2.6911458333333336.
# Expected x_min for bbox [3.0713541666666666, 1.6833333333333333, 3.6182291666666666, 2.5444444444444443, 'face'] to be in the range [0.0, 1.0], got 3.0713541666666666.
# Expected x_min for bbox [2.6651041666666666, 2.620833333333333, 3.1755208333333336, 3.3569444444444443, 'face'] to be in the range [0.0, 1.0], got 2.6651041666666666.
# Expected x_min for bbox [1.5566576086956523, 3.0119565217391306, 2.1341032608695647, 3.691304347826087, 'face'] to be in the range [0.0, 1.0], got 1.5566576086956523.
# Expected x_min for bbox [2.7744791666666666, 2.0236111111111112, 3.2536458333333336, 2.6902777777777778, 'face'] to be in the range [0.0, 1.0], got 2.7744791666666666.
# Expected x_min for bbox [2.7015625, 1.9125, 3.0817708333333336, 2.5444444444444443, 'face'] to be in the range [0.0, 1.0], got 2.7015625.
# Expected x_min for bbox [2.4463541666666666, 1.9958333333333333, 2.9046875, 2.7319444444444443, 'face'] to be in the range [0.0, 1.0], got 2.4463541666666666.
# Expected x_min for bbox [2.6182291666666666, 2.3638888888888885, 3.0869791666666666, 3.1, 'face'] to be in the range [0.0, 1.0], got 2.6182291666666666.
# Expected x_min for bbox [2.5817708333333336, 2.183333333333333, 2.9828125, 2.8152777777777778, 'face'] to be in the range [0.0, 1.0], got 2.5817708333333336.
# Expected x_min for bbox [2.6182291666666666, 2.183333333333333, 2.9255208333333336, 2.7875, 'face'] to be in the range [0.0, 1.0], got 2.6182291666666666.
# Expected x_min for bbox [1.9099184782608696, 3.030072463768116, 2.202038043478261, 3.691304347826087, 'face'] to be in the range [0.0, 1.0], got 1.9099184782608696.
# Expected x_min for bbox [2.8734375, 2.3916666666666666, 3.2901041666666666, 3.1694444444444443, 'face'] to be in the range [0.0, 1.0], got 2.8734375.
# Expected x_min for bbox [2.7067708333333336, 2.495833333333333, 3.2015625, 3.183333333333333, 'face'] to be in the range [0.0, 1.0], got 2.7067708333333336.
# Expected x_min for bbox [2.6963541666666666, 2.5375, 3.1651041666666666, 3.225, 'face'] to be in the range [0.0, 1.0], got 2.6963541666666666.
# Expected x_min for bbox [3.1859375, 2.4680555555555554, 3.6911458333333336, 3.134722222222222, 'face'] to be in the range [0.0, 1.0], got 3.1859375.
# Expected x_min for bbox [3.2484375, 2.475, 3.7432291666666666, 3.197222222222222, 'face'] to be in the range [0.0, 1.0], got 3.2484375.
# Expected x_min for bbox [2.1963541666666666, 2.759722222222222, 2.6078125, 3.3569444444444443, 'face'] to be in the range [0.0, 1.0], got 2.1963541666666666.
# Expected x_min for bbox [2.2119791666666666, 2.6138888888888885, 2.5921875, 3.3430555555555554, 'face'] to be in the range [0.0, 1.0], got 2.2119791666666666.
# Expected x_min for bbox [3.968342391304347, 3.1478260869565218, 4.1585597826086955, 3.519202898550725, 'face'] to be in the range [0.0, 1.0], got 3.968342391304347.
# Expected x_min for bbox [3.764538043478261, 3.0210144927536233, 3.9072010869565217, 3.2384057971014495, 'face'] to be in the range [0.0, 1.0], got 3.764538043478261.
# Expected x_min for bbox [3.9547554347826077, 2.9938405797101453, 4.124592391304347, 3.220289855072464, 'face'] to be in the range [0.0, 1.0], got 3.9547554347826077.
# Expected x_min for bbox [1.651766304347826, 1.9702898550724641, 1.8012228260869563, 2.160507246376812, 'face'] to be in the range [0.0, 1.0], got 1.651766304347826.
# Expected x_min for bbox [2.2699728260869563, 1.6170289855072466, 2.616440217391304, 2.0971014492753626, 'face'] to be in the range [0.0, 1.0], got 2.2699728260869563.
# Expected x_min for bbox [2.942527173913043, 1.3362318840579712, 3.4860054347826077, 2.006521739130435, 'face'] to be in the range [0.0, 1.0], got 2.942527173913043.
# Expected x_min for bbox [3.7509510869565217, 1.8525362318840581, 4.036277173913044, 2.2057971014492757, 'face'] to be in the range [0.0, 1.0], got 3.7509510869565217.
# Expected x_min for bbox [2.0389945652173913, 1.9702898550724641, 2.2088315217391306, 2.1695652173913045, 'face'] to be in the range [0.0, 1.0], got 2.0389945652173913.
# Expected y_min for bbox [0.9792119565217391, 2.0246376811594207, 1.121875, 2.2329710144927537, 'face'] to be in the range [0.0, 1.0], got 2.0246376811594207.
# Expected x_min for bbox [1.6721467391304343, 1.9974637681159422, 1.875951086956522, 2.223913043478261, 'face'] to be in the range [0.0, 1.0], got 1.6721467391304343.
# Expected x_min for bbox [1.9710597826086953, 1.7981884057971016, 2.256385869565217, 2.1333333333333333, 'face'] to be in the range [0.0, 1.0], got 1.9710597826086953.
# Expected x_min for bbox [2.5009510869565217, 1.082608695652174, 3.241440217391305, 1.9431159420289856, 'face'] to be in the range [0.0, 1.0], got 2.5009510869565217.
# Expected x_min for bbox [3.4316576086956516, 1.9250000000000003, 3.7441576086956516, 2.2329710144927537, 'face'] to be in the range [0.0, 1.0], got 3.4316576086956516.
# Expected x_min for bbox [3.988671875, 1.5163194444444446, 5.7529947916666675, 4.432986111111111, 'face'] to be in the range [0.0, 1.0], got 3.988671875.
# Expected x_min for bbox [2.3089843750000005, 1.9503472222222225, 3.2009114583333327, 3.7645833333333334, 'face'] to be in the range [0.0, 1.0], got 2.3089843750000005.
# Expected y_min for bbox [0.8701822916666668, 2.488541666666667, 1.8207031250000003, 4.120486111111111, 'face'] to be in the range [0.0, 1.0], got 2.488541666666667.
# Expected y_min for bbox [0.9483072916666668, 1.742013888888889, 1.8792968750000003, 3.625694444444444, 'face'] to be in the range [0.0, 1.0], got 1.742013888888889.
# Expected x_min for bbox [2.6084635416666666, 1.3947916666666669, 3.383203125, 3.156944444444444, 'face'] to be in the range [0.0, 1.0], got 2.6084635416666666.
# Expected x_min for bbox [4.4053385416666675, 1.4989583333333336, 5.915755208333333, 4.077083333333333, 'face'] to be in the range [0.0, 1.0], got 4.4053385416666675.
# Expected x_min for bbox [1.522690217391304, 0.4847826086956525, 2.827038043478261, 2.4684782608695657, 'face'] to be in the range [0.0, 1.0], got 1.522690217391304.
# Expected x_min for bbox [1.3936141304347829, 4.0445652173913045, 1.6857336956521736, 4.32536231884058, 'face'] to be in the range [0.0, 1.0], got 1.3936141304347829.
# Expected x_min for bbox [1.5713541666666662, 2.9055555555555554, 1.8317708333333336, 3.197222222222222, 'face'] to be in the range [0.0, 1.0], got 1.5713541666666662.
# Expected x_min for bbox [1.5765624999999999, 3.0930555555555554, 1.769270833333333, 3.398611111111111, 'face'] to be in the range [0.0, 1.0], got 1.5765624999999999.
# Expected x_min for bbox [2.0661458333333336, 3.1555555555555554, 2.2901041666666666, 3.4819444444444443, 'face'] to be in the range [0.0, 1.0], got 2.0661458333333336.
# Expected x_min for bbox [2.1544836956521736, 3.002898550724638, 2.3922554347826086, 3.519202898550725, 'face'] to be in the range [0.0, 1.0], got 2.1544836956521736.
# Expected x_min for bbox [2.684375, 3.175, 2.901766304347826, 3.70036231884058, 'face'] to be in the range [0.0, 1.0], got 2.684375.
# Expected x_min for bbox [3.8732336956521736, 3.9268115942028983, 4.144972826086956, 4.388768115942029, 'face'] to be in the range [0.0, 1.0], got 3.8732336956521736.
# Expected x_min for bbox [1.0526041666666672, 0.8636574074074075, 2.971006944444445, 5.203935185185186, 'face'] to be in the range [0.0, 1.0], got 1.0526041666666672.
# Expected x_min for bbox [1.4258680555555556, 0.7479166666666668, 3.040451388888889, 4.787268518518519, 'face'] to be in the range [0.0, 1.0], got 1.4258680555555556.
# Expected x_min for bbox [2.8838541666666666, 3.086111111111111, 3.2171875, 3.725, 'face'] to be in the range [0.0, 1.0], got 2.8838541666666666.
# Expected x_min for bbox [3.3317708333333336, 3.398611111111111, 3.6442708333333336, 3.9402777777777778, 'face'] to be in the range [0.0, 1.0], got 3.3317708333333336.
# Expected x_min for bbox [3.3369791666666666, 3.447222222222222, 3.6182291666666666, 3.9263888888888885, 'face'] to be in the range [0.0, 1.0], got 3.3369791666666666.
# Expected x_min for bbox [3.3526041666666666, 3.495833333333333, 3.7171875, 3.947222222222222, 'face'] to be in the range [0.0, 1.0], got 3.3526041666666666.
# Expected x_min for bbox [3.4151041666666666, 3.4541666666666666, 3.8109375, 3.933333333333333, 'face'] to be in the range [0.0, 1.0], got 3.4151041666666666.
# Expected x_min for bbox [3.3942708333333336, 3.4819444444444443, 3.8213541666666666, 3.9680555555555554, 'face'] to be in the range [0.0, 1.0], got 3.3942708333333336.
# Expected x_min for bbox [3.3526041666666666, 3.433333333333333, 3.8109375, 3.961111111111111, 'face'] to be in the range [0.0, 1.0], got 3.3526041666666666.
# Expected x_min for bbox [1.5765624999999999, 2.6138888888888885, 2.0505208333333336, 3.2319444444444443, 'face'] to be in the range [0.0, 1.0], got 1.5765624999999999.
# Expected x_min for bbox [1.5869791666666662, 2.725, 1.9880208333333336, 3.225, 'face'] to be in the range [0.0, 1.0], got 1.5869791666666662.
# Expected x_min for bbox [1.6338541666666664, 2.6763888888888885, 2.1182291666666666, 3.2388888888888885, 'face'] to be in the range [0.0, 1.0], got 1.6338541666666664.
# Expected x_min for bbox [1.6546875, 2.6555555555555554, 1.9828125, 3.1763888888888885, 'face'] to be in the range [0.0, 1.0], got 1.6546875.
# Expected x_min for bbox [1.7944293478260867, 2.595289855072464, 2.6911684782608694, 4.678623188405797, 'face'] to be in the range [0.0, 1.0], got 1.7944293478260867.
# Expected x_min for bbox [1.196603260869565, 2.2420289855072464, 2.460190217391304, 4.5699275362318845, 'face'] to be in the range [0.0, 1.0], got 1.196603260869565.
# Expected x_min for bbox [1.2849184782608696, 1.5717391304347827, 2.7115489130434782, 4.289130434782608, 'face'] to be in the range [0.0, 1.0], got 1.2849184782608696.
# Expected x_min for bbox [3.917057291666667, 1.7854166666666669, 5.193098958333333, 3.790625, 'face'] to be in the range [0.0, 1.0], got 3.917057291666667.
# Expected x_min for bbox [1.9899739583333331, 0.9173611111111112, 3.383203125, 3.816666666666667, 'face'] to be in the range [0.0, 1.0], got 1.9899739583333331.
# Expected x_min for bbox [3.506901041666667, 2.384375, 4.236067708333333, 3.807986111111111, 'face'] to be in the range [0.0, 1.0], got 3.506901041666667.
# Expected x_min for bbox [4.476953125, 0.9434027777777778, 5.6944010416666675, 3.2177083333333334, 'face'] to be in the range [0.0, 1.0], got 4.476953125.
# Expected x_min for bbox [2.029036458333333, 0.413888888888889, 3.402734375, 3.391319444444444, 'face'] to be in the range [0.0, 1.0], got 2.029036458333333.
# Expected x_min for bbox [2.942527173913043, 3.790942028985507, 3.1735054347826077, 4.189492753623188, 'face'] to be in the range [0.0, 1.0], got 2.942527173913043.
# Expected x_min for bbox [1.352853260869565, 3.691304347826087, 1.7264945652173913, 4.098913043478261, 'face'] to be in the range [0.0, 1.0], got 1.352853260869565.
# Expected x_min for bbox [3.193885869565217, 2.9938405797101453, 4.009103260869566, 4.334420289855073, 'face'] to be in the range [0.0, 1.0], got 3.193885869565217.
# Expected x_min for bbox [2.2224184782608694, 2.622463768115942, 2.473777173913043, 3.1478260869565218, 'face'] to be in the range [0.0, 1.0], got 2.2224184782608694.
# Expected x_min for bbox [1.692527173913043, 2.622463768115942, 2.045788043478261, 3.256521739130435, 'face'] to be in the range [0.0, 1.0], got 1.692527173913043.
# Expected y_min for bbox [0.5104619565217391, 2.9123188405797102, 0.9248641304347828, 3.96304347826087, 'face'] to be in the range [0.0, 1.0], got 2.9123188405797102.
# Expected x_min for bbox [1.0471467391304343, 2.9032608695652176, 1.3936141304347829, 3.70036231884058, 'face'] to be in the range [0.0, 1.0], got 1.0471467391304343.
# Expected y_min for bbox [0.2047554347826086, 3.0934782608695657, 0.8161684782608696, 4.098913043478261, 'face'] to be in the range [0.0, 1.0], got 3.0934782608695657.
# Expected x_min for bbox [1.3868206521739126, 3.1568840579710145, 1.8283967391304343, 3.9177536231884056, 'face'] to be in the range [0.0, 1.0], got 1.3868206521739126.
# Expected x_min for bbox [2.4669836956521736, 4.017391304347826, 2.8134510869565217, 4.551811594202899, 'face'] to be in the range [0.0, 1.0], got 2.4669836956521736.
# Expected x_min for bbox [3.2074728260869563, 3.2021739130434788, 3.934375, 4.280072463768116, 'face'] to be in the range [0.0, 1.0], got 3.2074728260869563.
# Expected x_min for bbox [2.9153532608695647, 3.473913043478261, 3.3025815217391297, 4.252898550724638, 'face'] to be in the range [0.0, 1.0], got 2.9153532608695647.
# Expected x_min for bbox [2.6504076086956516, 2.776449275362319, 2.956114130434782, 3.1568840579710145, 'face'] to be in the range [0.0, 1.0], got 2.6504076086956516.
# Expected x_min for bbox [1.9846467391304343, 2.71304347826087, 2.276766304347826, 3.310869565217392, 'face'] to be in the range [0.0, 1.0], got 1.9846467391304343.
# Expected x_min for bbox [1.875951086956522, 3.1478260869565218, 2.045788043478261, 3.691304347826087, 'face'] to be in the range [0.0, 1.0], got 1.875951086956522.
# Expected x_max for bbox [0.5244791666666663, 0.8708333333333332, 1.0296874999999999, 1.7875, 'face'] to be in the range [0.0, 1.0], got 1.0296874999999999.
# Expected x_min for bbox [1.3161458333333331, 1.725, 1.5765624999999999, 2.2944444444444443, 'face'] to be in the range [0.0, 1.0], got 1.3161458333333331.
# Expected x_min for bbox [1.6807291666666664, 1.9055555555555554, 1.9932291666666664, 2.433333333333333, 'face'] to be in the range [0.0, 1.0], got 1.6807291666666664.
# Expected x_min for bbox [3.7432291666666666, 1.0791666666666666, 4.3265625, 1.9333333333333333, 'face'] to be in the range [0.0, 1.0], got 3.7432291666666666.
# Expected x_min for bbox [3.0817708333333336, 1.725, 3.4671875, 2.3569444444444443, 'face'] to be in the range [0.0, 1.0], got 3.0817708333333336.
# Expected x_min for bbox [2.6598958333333336, 1.9541666666666666, 2.9619791666666666, 2.509722222222222, 'face'] to be in the range [0.0, 1.0], got 2.6598958333333336.
# Expected x_min for bbox [2.3942708333333336, 2.183333333333333, 2.6807291666666666, 2.6, 'face'] to be in the range [0.0, 1.0], got 2.3942708333333336.
# Expected y_min for bbox [0.5251302083333332, 1.1690972222222225, 1.2087239583333331, 2.3409722222222222, 'face'] to be in the range [0.0, 1.0], got 1.1690972222222225.
# Expected x_min for bbox [4.672265625, 1.8375000000000001, 6.176171875, 4.571875000000001, 'face'] to be in the range [0.0, 1.0], got 4.672265625.
# Expected x_min for bbox [1.6774739583333331, 1.7506944444444446, 2.068098958333333, 2.5493055555555557, 'face'] to be in the range [0.0, 1.0], got 1.6774739583333331.
# Expected x_min for bbox [3.617578125, 1.8288194444444446, 4.1123697916666675, 2.766319444444444, 'face'] to be in the range [0.0, 1.0], got 3.617578125.
# Expected x_min for bbox [3.422265625, 2.167361111111111, 3.6696614583333327, 2.696875, 'face'] to be in the range [0.0, 1.0], got 3.422265625.
# Expected x_min for bbox [3.161848958333333, 2.2368055555555557, 3.441796875, 2.7402777777777776, 'face'] to be in the range [0.0, 1.0], got 3.161848958333333.
# Expected x_min for bbox [2.0811197916666666, 2.2802083333333334, 2.400130208333333, 2.8965277777777776, 'face'] to be in the range [0.0, 1.0], got 2.0811197916666666.
# Expected x_min for bbox [2.5303385416666666, 2.3930555555555557, 2.8167968750000005, 2.8878472222222222, 'face'] to be in the range [0.0, 1.0], got 2.5303385416666666.
# Expected x_min for bbox [5.017317708333333, 2.479861111111111, 6.4756510416666675, 4.840972222222223, 'face'] to be in the range [0.0, 1.0], got 5.017317708333333.
# Expected x_min for bbox [4.6006510416666675, 0.8739583333333335, 5.3428385416666675, 2.1847222222222222, 'face'] to be in the range [0.0, 1.0], got 4.6006510416666675.
# Expected x_min for bbox [4.118880208333333, 1.7940972222222225, 4.5811197916666675, 2.4625, 'face'] to be in the range [0.0, 1.0], got 4.118880208333333.
# Expected x_min for bbox [3.461328125, 2.0631944444444446, 3.891015625, 2.8270833333333334, 'face'] to be in the range [0.0, 1.0], got 3.461328125.
# Expected x_min for bbox [2.2569010416666666, 2.401736111111111, 2.614973958333333, 3.156944444444444, 'face'] to be in the range [0.0, 1.0], got 2.2569010416666666.
# Expected x_min for bbox [2.7451822916666666, 2.5753472222222222, 3.044661458333333, 3.1743055555555557, 'face'] to be in the range [0.0, 1.0], got 2.7451822916666666.
# ...
# Expected y_min for bbox [0.340625, 3.3199275362318845, 0.5716032608695649, 3.6188405797101453, 'face'] to be in the range [0.0, 1.0], got 3.3199275362318845.
# Expected x_min for bbox [1.2713315217391306, 3.3833333333333333, 1.3868206521739126, 3.5554347826086956, 'face'] to be in the range [0.0, 1.0], got 1.2713315217391306.
# Expected x_min for bbox [1.6993206521739126, 3.410507246376812, 1.8691576086956523, 3.609782608695652, 'face'] to be in the range [0.0, 1.0], got 1.6993206521739126.
# Expected x_min for bbox [1.0743206521739133, 3.3561594202898553, 1.223777173913043, 3.5735507246376814, 'face'] to be in the range [0.0, 1.0], got 1.0743206521739133.
# Expected y_min for bbox [0.9927989130434781, 3.6007246376811595, 1.2033967391304343, 3.908695652173913, 'face'] to be in the range [0.0, 1.0], got 3.6007246376811595.
# Expected y_min for bbox [0.6735054347826086, 3.1478260869565218, 1.3120923913043476, 3.9268115942028983, 'face'] to be in the range [0.0, 1.0], got 3.1478260869565218.
# Expected x_min for bbox [1.3936141304347829, 1.9884057971014495, 2.4466032608695647, 4.425, 'face'] to be in the range [0.0, 1.0], got 1.3936141304347829.
# Expected x_min for bbox [3.7985054347826077, 4.126086956521739, 4.246875, 4.832608695652174, 'face'] to be in the range [0.0, 1.0], got 3.7985054347826077.
# Expected x_min for bbox [2.6504076086956516, 2.513768115942029, 3.2618206521739124, 3.4829710144927537, 'face'] to be in the range [0.0, 1.0], got 2.6504076086956516.
# Expected y_min for bbox [0.6735054347826086, 3.591666666666667, 1.1150815217391306, 4.153260869565218, 'face'] to be in the range [0.0, 1.0], got 3.591666666666667.
# Expected x_min for bbox [2.0088541666666666, 1.4125, 3.8838541666666666, 3.975, 'face'] to be in the range [0.0, 1.0], got 2.0088541666666666.
# Expected x_min for bbox [1.2373641304347829, 2.4956521739130437, 2.4533967391304343, 4.479347826086956, 'face'] to be in the range [0.0, 1.0], got 1.2373641304347829.
# Expected x_min for bbox [1.8283967391304343, 2.2782608695652176, 2.256385869565217, 2.776449275362319, 'face'] to be in the range [0.0, 1.0], got 1.8283967391304343.
# [Errno 2] No such file or directory: 'aug_data\\test\\labels\\IMG_20191011_012000_face1_0.json'
# Expected y_max for bbox [0.014538043478260931, 0.4485507246376815, 0.19116847826086952, 1.2003623188405799, 'face'] to be in the range [0.0, 1.0], got 1.2003623188405799.
# Expected x_min for bbox [1.7808423913043476, 1.453985507246377, 2.9764945652173913, 3.4920289855072464, 'face'] to be in the range [0.0, 1.0], got 1.7808423913043476.
# Expected x_min for bbox [2.7794836956521736, 4.144202898550725, 3.1259510869565217, 4.633333333333334, 'face'] to be in the range [0.0, 1.0], got 2.7794836956521736.
# Expected x_min for bbox [3.3637228260869563, 4.560869565217391, 3.7713315217391297, 4.977536231884058, 'face'] to be in the range [0.0, 1.0], got 3.3637228260869563.
# Expected y_min for bbox [0.6123641304347828, 4.06268115942029, 0.7142663043478258, 4.216666666666667, 'face'] to be in the range [0.0, 1.0], got 4.06268115942029.
# Expected y_min for bbox [0.809375, 4.026449275362319, 0.911277173913043, 4.180434782608696, 'face'] to be in the range [0.0, 1.0], got 4.026449275362319.
# Expected y_min for bbox [0.5036684782608696, 4.425, 0.741440217391304, 4.678623188405797, 'face'] to be in the range [0.0, 1.0], got 4.425.
# Expected y_min for bbox [0.25230978260869535, 4.58804347826087, 0.42894021739130395, 4.886956521739131, 'face'] to be in the range [0.0, 1.0], got 4.58804347826087.
# Expected x_min for bbox [2.8677989130434782, 4.415942028985508, 3.1055706521739124, 4.732971014492754, 'face'] to be in the range [0.0, 1.0], got 2.8677989130434782.
# Expected x_min for bbox [3.3297554347826077, 4.551811594202899, 3.5267663043478263, 4.8778985507246375, 'face'] to be in the range [0.0, 1.0], got 3.3297554347826077.
# Expected x_min for bbox [1.760461956521739, 4.506521739130434, 1.9302989130434782, 4.705797101449275, 'face'] to be in the range [0.0, 1.0], got 1.760461956521739.
# Expected x_min for bbox [2.093342391304348, 4.470289855072464, 2.1952445652173913, 4.678623188405797, 'face'] to be in the range [0.0, 1.0], got 2.093342391304348.
# Expected y_min for bbox [0.014538043478260931, 5.149637681159421, 0.21154891304347814, 5.367028985507247, 'face'] to be in the range [0.0, 1.0], got 5.149637681159421.
# [Errno 2] No such file or directory: 'aug_data\\val\\labels\\FB_IMG_1568570861533_face0_0.json'
# [Errno 2] No such file or directory: 'aug_data\\val\\labels\\FB_IMG_1568570861533_face1_0.json'
# Expected y_max for bbox [0.13984375, 0.6166666666666667, 0.48359375, 1.0458333333333334, 'face'] to be in the range [0.0, 1.0], got 1.0458333333333334.
# Expected y_max for bbox [0.57890625, 0.66875, 0.91484375, 1.1583333333333334, 'face'] to be in the range [0.0, 1.0], got 1.1583333333333334.
# Expected y_min for bbox [0.48046875, 1.2145833333333333, 0.62734375, 1.4395833333333334, 'face'] to be in the range [0.0, 1.0], got 1.2145833333333333.
# Expected y_min for bbox [0.66953125, 1.59375, 0.84296875, 1.78125, 'face'] to be in the range [0.0, 1.0], got 1.59375.
# Expected x_min for bbox [3.7673177083333336, 1.0345486111111113, 5.772526041666667, 3.977256944444444, 'face'] to be in the range [0.0, 1.0], got 3.7673177083333336.
# Expected y_min for bbox [0.9938802083333332, 2.3887152777777776, 1.3845052083333331, 2.649131944444444, 'face'] to be in the range [0.0, 1.0], got 2.3887152777777776.
# Expected x_min for bbox [1.6970052083333336, 1.0953125000000001, 3.2529947916666666, 3.7602430555555557, 'face'] to be in the range [0.0, 1.0], got 1.6970052083333336.
# Expected x_min for bbox [3.6696614583333336, 0.7220486111111112, 4.574609375, 2.9008680555555557, 'face'] to be in the range [0.0, 1.0], got 3.6696614583333336.
# Expected x_min for bbox [4.815494791666667, 2.7880208333333334, 6.449609375, 5.583159722222223, 'face'] to be in the range [0.0, 1.0], got 4.815494791666667.
# Expected x_min for bbox [5.798567708333334, 1.8765625000000001, 6.0980468750000005, 2.1890625, 'face'] to be in the range [0.0, 1.0], got 5.798567708333334.
# Expected x_min for bbox [6.1175781250000005, 1.9894097222222225, 6.384505208333334, 2.249826388888889, 'face'] to be in the range [0.0, 1.0], got 6.1175781250000005.
# Expected x_min for bbox [1.0743206521739133, 2.803623188405797, 1.380027173913043, 3.2112318840579714, 'face'] to be in the range [0.0, 1.0], got 1.0743206521739133.
# Expected x_min for bbox [3.2618206521739124, 4.017391304347826, 3.5879076086956516, 4.560869565217391, 'face'] to be in the range [0.0, 1.0], got 3.2618206521739124.
# Expected x_min for bbox [3.397690217391305, 4.524637681159421, 3.9004076086956516, 5.167753623188406, 'face'] to be in the range [0.0, 1.0], got 3.397690217391305.
# Expected x_min for bbox [2.9764945652173913, 3.473913043478261, 3.2210597826086955, 3.790942028985507, 'face'] to be in the range [0.0, 1.0], got 2.9764945652173913.
# Expected x_min for bbox [3.8392663043478263, 3.428623188405797, 3.975135869565217, 3.6731884057971014, 'face'] to be in the range [0.0, 1.0], got 3.8392663043478263.
# Expected x_min for bbox [3.6490489130434782, 3.8362318840579714, 3.893614130434783, 4.271014492753623, 'face'] to be in the range [0.0, 1.0], got 3.6490489130434782.
# Expected x_min for bbox [1.4619791666666662, 1.5930555555555554, 2.3213541666666666, 2.7666666666666666, 'face'] to be in the range [0.0, 1.0], got 1.4619791666666662.
# Expected x_min for bbox [3.019021739130435, 1.2728260869565218, 3.460597826086957, 1.9793478260869568, 'face'] to be in the range [0.0, 1.0], got 3.019021739130435.
# Expected x_min for bbox [3.3786458333333336, 1.0583333333333331, 3.8005208333333336, 1.9402777777777778, 'face'] to be in the range [0.0, 1.0], got 3.3786458333333336.
# Expected x_min for bbox [3.9880208333333336, 1.1625, 4.461979166666667, 1.9402777777777778, 'face'] to be in the range [0.0, 1.0], got 3.9880208333333336.
# Expected x_min for bbox [5.4515625000000005, 0.5027777777777777, 5.524479166666667, 0.5791666666666665, 'face'] to be in the range [0.0, 1.0], got 5.4515625000000005.
# Expected y_min for bbox [0.8773097826086953, 2.2782608695652176, 1.0131793478260867, 2.6677536231884056, 'face'] to be in the range [0.0, 1.0], got 2.2782608695652176.
# Expected y_min for bbox [0.5036684782608696, 2.341666666666667, 0.7210597826086953, 2.6134057971014495, 'face'] to be in the range [0.0, 1.0], got 2.341666666666667.
# Expected x_min for bbox [2.4262228260869563, 3.2655797101449275, 2.5009510869565217, 3.4557971014492757, 'face'] to be in the range [0.0, 1.0], got 2.4262228260869563.
# Expected x_min for bbox [2.772690217391304, 2.8670289855072464, 3.0240489130434782, 3.328985507246377, 'face'] to be in the range [0.0, 1.0], got 2.772690217391304.
# Expected x_min for bbox [2.0661684782608694, 2.8579710144927537, 2.2088315217391306, 3.0210144927536233, 'face'] to be in the range [0.0, 1.0], got 2.0661684782608694.
# Expected x_min for bbox [2.358288043478261, 2.9032608695652176, 2.5349184782608694, 3.1206521739130437, 'face'] to be in the range [0.0, 1.0], got 2.358288043478261.
# Expected y_min for bbox [0.25230978260869535, 2.8398550724637683, 0.48328804347826093, 3.057246376811594, 'face'] to be in the range [0.0, 1.0], got 2.8398550724637683.
# Expected y_min for bbox [0.7889945652173914, 3.2384057971014495, 0.9860054347826086, 3.5282608695652176, 'face'] to be in the range [0.0, 1.0], got 3.2384057971014495.
# Expected x_min for bbox [1.7061141304347829, 2.432246376811594, 1.9302989130434782, 2.921376811594203, 'face'] to be in the range [0.0, 1.0], got 1.7061141304347829.
# Expected x_min for bbox [2.8134510869565217, 2.622463768115942, 3.003668478260869, 2.9032608695652176, 'face'] to be in the range [0.0, 1.0], got 2.8134510869565217.
# Expected x_min for bbox [1.9846467391304343, 2.0246376811594207, 2.6775815217391306, 2.7945652173913045, 'face'] to be in the range [0.0, 1.0], got 1.9846467391304343.
# Expected x_min for bbox [1.8859375, 1.546527777777778, 3.830381944444445, 4.625231481481482, 'face'] to be in the range [0.0, 1.0], got 1.8859375.
# Expected y_min for bbox [0.18454861111111143, 2.0094907407407407, 0.9744791666666671, 3.6645833333333333, 'face'] to be in the range [0.0, 1.0], got 2.0094907407407407.
# Expected x_min for bbox [2.0661684782608694, 2.5862318840579714, 2.3107336956521736, 3.1478260869565218, 'face'] to be in the range [0.0, 1.0], got 2.0661684782608694.
# Expected x_min for bbox [2.5213315217391306, 2.894202898550725, 2.697961956521739, 3.27463768115942, 'face'] to be in the range [0.0, 1.0], got 2.5213315217391306.
# Expected x_min for bbox [4.056657608695652, 3.066304347826087, 4.178940217391305, 3.247463768115942, 'face'] to be in the range [0.0, 1.0], got 4.056657608695652.
# Expected x_min for bbox [2.9723958333333336, 2.8152777777777778, 3.2640625, 3.322222222222222, 'face'] to be in the range [0.0, 1.0], got 2.9723958333333336.
# Expected x_min for bbox [3.4151041666666666, 3.4055555555555554, 3.7848958333333336, 3.947222222222222, 'face'] to be in the range [0.0, 1.0], got 3.4151041666666666.
# Expected x_min for bbox [1.6381793478260867, 2.45036231884058, 2.8949728260869563, 4.633333333333334, 'face'] to be in the range [0.0, 1.0], got 1.6381793478260867.
# Expected y_min for bbox [0.9828124999999999, 1.4125, 1.4723958333333331, 2.3638888888888885, 'face'] to be in the range [0.0, 1.0], got 1.4125.
# Expected x_min for bbox [1.5453124999999999, 1.7944444444444445, 1.8473958333333336, 2.35, 'face'] to be in the range [0.0, 1.0], got 1.5453124999999999.
# Expected x_min for bbox [1.9984375, 2.211111111111111, 2.2953125, 2.7388888888888885, 'face'] to be in the range [0.0, 1.0], got 1.9984375.
# Expected x_min for bbox [2.9463541666666666, 2.5166666666666666, 3.2328125, 2.8777777777777778, 'face'] to be in the range [0.0, 1.0], got 2.9463541666666666.
# Expected x_min for bbox [3.3213541666666666, 2.3569444444444443, 3.5505208333333336, 2.870833333333333, 'face'] to be in the range [0.0, 1.0], got 3.3213541666666666.
# Expected x_min for bbox [3.6234375, 1.975, 4.024479166666667, 2.634722222222222, 'face'] to be in the range [0.0, 1.0], got 3.6234375.
# Expected x_min for bbox [4.1546875, 1.3152777777777778, 4.831770833333334, 2.586111111111111, 'face'] to be in the range [0.0, 1.0], got 4.1546875.
# Expected x_min for bbox [1.8597656250000003, 2.5927083333333334, 3.0121093750000005, 5.066666666666667, 'face'] to be in the range [0.0, 1.0], got 1.8597656250000003.
# Expected x_min for bbox [3.624088541666667, 1.0996527777777778, 5.9873697916666675, 4.215972222222223, 'face'] to be in the range [0.0, 1.0], got 3.624088541666667.
# Expected x_min for bbox [1.6721467391304343, 1.743840579710145, 2.385461956521739, 3.1840579710144925, 'face'] to be in the range [0.0, 1.0], got 1.6721467391304343.
# Expected y_min for bbox [0.2015624999999998, 2.85, 0.3369791666666663, 3.120833333333333, 'face'] to be in the range [0.0, 1.0], got 2.85.
# Expected y_min for bbox [0.738020833333333, 2.6555555555555554, 0.8526041666666663, 2.8152777777777778, 'face'] to be in the range [0.0, 1.0], got 2.6555555555555554.
# Expected y_min for bbox [0.8369791666666663, 2.447222222222222, 0.9515624999999999, 2.6625, 'face'] to be in the range [0.0, 1.0], got 2.447222222222222.
# Expected y_min for bbox [0.9359374999999999, 2.586111111111111, 1.0817708333333331, 2.836111111111111, 'face'] to be in the range [0.0, 1.0], got 2.586111111111111.
# Expected x_min for bbox [1.5838315217391306, 2.3688405797101453, 2.7047554347826086, 4.633333333333334, 'face'] to be in the range [0.0, 1.0], got 1.5838315217391306.
# Expected y_min for bbox [0.19116847826086952, 2.5047101449275364, 0.9520380434782609, 3.8271739130434788, 'face'] to be in the range [0.0, 1.0], got 2.5047101449275364.
# Expected y_min for bbox [0.13002717391304372, 3.655072463768116, 0.9927989130434781, 5.276449275362319, 'face'] to be in the range [0.0, 1.0], got 3.655072463768116.
# Expected x_min for bbox [1.291711956521739, 1.9431159420289856, 2.562092391304348, 3.609782608695652, 'face'] to be in the range [0.0, 1.0], got 1.291711956521739.
# Expected x_min for bbox [3.8052989130434782, 3.4829710144927537, 4.0023097826086955, 3.7094202898550726, 'face'] to be in the range [0.0, 1.0], got 3.8052989130434782.
# Expected y_min for bbox [0.5444293478260868, 1.6985507246376814, 0.9792119565217391, 2.3688405797101453, 'face'] to be in the range [0.0, 1.0], got 1.6985507246376814.
# Expected x_min for bbox [2.8338315217391306, 4.135144927536232, 3.2754076086956516, 4.68768115942029, 'face'] to be in the range [0.0, 1.0], got 2.8338315217391306.
# Expected x_min for bbox [3.6490489130434782, 4.7239130434782615, 3.7713315217391297, 4.8778985507246375, 'face'] to be in the range [0.0, 1.0], got 3.6490489130434782.
# Expected y_min for bbox [0.46290760869565234, 4.053623188405798, 0.5376358695652173, 4.180434782608696, 'face'] to be in the range [0.0, 1.0], got 4.053623188405798.
# Expected y_min for bbox [0.6463315217391304, 4.035507246376811, 0.7346467391304344, 4.171376811594203, 'face'] to be in the range [0.0, 1.0], got 4.035507246376811.
# Expected x_min for bbox [3.581114130434783, 4.352536231884058, 3.628668478260869, 4.470289855072464, 'face'] to be in the range [0.0, 1.0], got 3.581114130434783.
# Expected y_min for bbox [0.5104619565217391, 3.4829710144927537, 0.7686141304347828, 3.8, 'face'] to be in the range [0.0, 1.0], got 3.4829710144927537.
# Expected x_min for bbox [1.9846467391304343, 2.5771739130434788, 2.562092391304348, 3.7728260869565218, 'face'] to be in the range [0.0, 1.0], got 1.9846467391304343.
# Expected x_min for bbox [2.6232336956521736, 3.7184782608695652, 2.799864130434782, 4.0445652173913045, 'face'] to be in the range [0.0, 1.0], got 2.6232336956521736.
# Expected x_min for bbox [3.7509510869565217, 3.9177536231884056, 3.981929347826086, 4.243840579710144, 'face'] to be in the range [0.0, 1.0], got 3.7509510869565217.
